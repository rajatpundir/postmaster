# %%
import os
import time
import json
import requests
import hashlib
from datetime import datetime, timedelta
from watchdog.observers import Observer
from watchdog.events import PatternMatchingEventHandler
from keycloak import KeycloakOpenID

tests_filename = './tests.json'
config_filename = './pibity-erp/src/main/resources/postmaster.json'


with open('./pibity-erp/src/main/resources/postmaster.json', 'r') as config_file:
    config = json.loads(config_file.read())
    config_hash = hashlib.sha256(json.dumps(
        config).encode('utf-8')).hexdigest()

client_secret = config['keycloakClientSecret']
run_count = int(config['runCount'])

keycloak_openid = KeycloakOpenID(server_url="http://localhost:8081/auth/",
                    client_id="pibity-erp-admin",
                    realm_name="inventory",
                    client_secret_key=client_secret,
                    verify=True)
token = 'Bearer ' + keycloak_openid.token("superuser@pibity.com", "1234")['access_token']


def execute_tests(hash_override=False):
    global token
    headers = {'content-type': 'application/json', 'Authorization': token}
    with open(tests_filename, 'r') as tests_json, open('urls.json', 'r') as urls_json:
        tests = json.loads(tests_json.read())
        urls = json.loads(urls_json.read())
    test_outputs = []
    step = 0
    orgId = 1
    prev_block_hash = ''
    for index, test in enumerate(tests):
        step += 1
        url = urls['server'] + test['url']
        request = test['request']
        # Hash is computed based only on URL and Request Body (Needs to be calculated before further modifying above structure)
        test_output_hash = hashlib.sha256(json.dumps(
            {'url': test['url'], 'request': test['request'], 'prev_block_hash': prev_block_hash}).encode('utf-8')).hexdigest()
        prev_block_hash = test_output_hash
        test_output = {}
        test_output['step'] = step
        if not hash_override and 'hash' in test and test['hash'] == test_output_hash:
            if test['url'] == 'organization/create':
                orgId = int(test['response']['id'])
            test_outputs.append(test)
            with open(tests_filename, 'w') as output:
                temp_tests = test_outputs.copy()
                temp_tests.extend(tests[(index+1):])
                output.write(json.dumps(temp_tests, indent=4))
            print('SKIPPING STEP', step, '\n')
            continue
        if test['url'] != 'organization/create':
            request['orgId'] = orgId
        print('\n', 'STEP   :', step)
        print('\n', 'HASH   :', test_output_hash)
        print('\n', 'URL    :', url)
        print('\n', 'REQUEST:', json.dumps(request, indent=1))
        try:
            response = requests.post(url, data=json.dumps(request), headers=headers)
        except:
            return
        if response.status_code == 200 and test['url'] == 'organization/create':
            orgId = int(response.json()['id'])
            token = 'Bearer ' + \
                keycloak_openid.token(
                    "superuser@pibity.com", "1234")['access_token']
        if response.status_code == 200:
            print('\n', 'RESPONSE:', json.dumps(response.json(), indent=1))
            test_output['hash'] = test_output_hash
            test_output['response'] = response.json()
        else:
            test_output_response = {}
            test_output_response['statusCode'] = response.status_code
            print('\n', 'STATUS CODE:', response.status_code)
            try:
                if 'message' in response.json():
                    test_output_response['error'] = response.json()['message']
                else:
                    test_output_response['error'] = response.json()
                print('\n', 'ERROR:', json.dumps(test_output_response['error'], indent=1))
            except:
                test_output_response['error'] = response.text
                pass
            test_output['response'] = test_output_response
            test_output['url'] = test['url']
            test_output['request'] = request
            test_outputs.append(test_output)
            with open(tests_filename, 'w') as output:
                temp_tests = test_outputs.copy()
                for temp_test in tests[(index+1):]:
                    t = {}
                    t['url'] = temp_test['url']
                    t['request'] = temp_test['request']
                    temp_tests.append(t)
                output.write(json.dumps(temp_tests, indent = 4))
            print('\n', 'STOPPING EXECUTION')
            break
        test_output['url'] = test['url']
        test_output['request'] = request
        test_outputs.append(test_output)
        print('\n', '--------------------------------------------')
        with open(tests_filename, 'w') as output:
            temp_tests = test_outputs.copy()
            for temp_test in tests[(index+1):]:
                t = {}
                t['hash'] = test_output_hash
                t['url'] = temp_test['url']
                t['request'] = temp_test['request']
                temp_tests.append(t)
            output.write(json.dumps(temp_tests, indent = 4))

execute_tests(hash_override = True)

class MyEventHandler(PatternMatchingEventHandler):
    def on_any_event(self, event):
        global config, client_secret, run_count, keycloak_openid, token
#         print(f'Event type: {event.event_type}  path : {event.src_path}')
        if event.src_path == (tests_filename):
            print('\n', 'DETECTED: CHANGE IN TESTS')
            execute_tests()
            time.sleep(6)
        elif event.src_path == (config_filename):
            with open('./pibity-erp/src/main/resources/postmaster.json', 'r') as config_file:
                config = json.loads(config_file.read())
            if config_hash != hashlib.sha256(json.dumps(config).encode('utf-8')).hexdigest():
                if client_secret != config['keycloakClientSecret']:
                    print('\n', 'DETECTED: TOKEN UPDATE')
                    client_secret = config['keycloakClientSecret']
                    keycloak_openid = KeycloakOpenID(server_url="http://localhost:8081/auth/",
                                        client_id="pibity-erp-admin",
                                        realm_name="inventory",
                                        client_secret_key=client_secret,
                                        verify=True)
                    token = 'Bearer ' + keycloak_openid.token("superuser@pibity.com", "1234")['access_token']
                if run_count != config['runCount']:
                    run_count = config['runCount']
                    print('\n', 'DETECTED: SERVER RESTART')
                    time.sleep(6)
                    execute_tests(hash_override = True)


event_handler = MyEventHandler(patterns=['*.json'], ignore_patterns=[], ignore_directories=True)
observer = Observer()
observer.schedule(event_handler, '.', recursive=True)
observer.start()
try:
    while True:
        time.sleep(1)
finally:
    observer.stop()
    observer.join()
# Out:
# config {'keycloakClientSecret': '5b214fdc-1000-4fd2-8d6d-fc644b674d96', 'runCount': 28}
# STEP 1
#
# Hash= 0765103a979481c6cea94f4322bd5b69f2365d5f934e69e388dcebdb2b347565
# URL: http://localhost:8080/api/organization/create
#
# REQUEST: {
#  "organization": "pibity",
#  "admin": "admin@xyz.com",
#  "firstName": "Admin",
#  "lastName": "",
#  "password": "1234",
#  "details": {}
# }
#
# RESPONSE: {
#  "id": 1,
#  "name": "pibity"
# }
# -------------------------------------
#
# STEP 2
#
# Hash= ffb586769be7fc3963c3ee203d23ad2e82d8b97bb90605b5bef1c6b310d8747c
# URL: http://localhost:8080/api/type/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "A",
#  "displayName": "A",
#  "autoId": true,
#  "keys": {
#   "x": {
#    "type": "Number",
#    "order": "1"
#   },
#   "y": {
#    "type": "Number",
#    "order": "2"
#   },
#   "z": {
#    "type": "Number",
#    "order": "3"
#   },
#   "d": {
#    "type": "Formula",
#    "order": "4",
#    "returnType": "Number",
#    "expression": {
#     "op": "+",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "x"
#       ]
#      },
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "y"
#       ]
#      }
#     ]
#    }
#   }
#  },
#  "permissions": [],
#  "roles": {
#   "ADMIN": [
#    "WRITE_ALL"
#   ],
#   "USER": [
#    "READ_ALL"
#   ]
#  }
# }
#
# RESPONSE: {
#  "orgId": 1,
#  "typeName": "A",
#  "keys": {
#   "x": {
#    "order": 1,
#    "type": "Number",
#    "default": 0
#   },
#   "y": {
#    "order": 2,
#    "type": "Number",
#    "default": 0
#   },
#   "z": {
#    "order": 3,
#    "type": "Number",
#    "default": 0
#   },
#   "d": {
#    "order": 4,
#    "type": "Formula",
#    "returnType": "Number",
#    "expression": {
#     "op": "+",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "x"
#       ]
#      },
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "y"
#       ]
#      }
#     ]
#    },
#    "symbols": [
#     "x",
#     "y"
#    ]
#   }
#  },
#  "permissions": [
#   {
#    "orgId": 1,
#    "typeName": "A",
#    "permissionName": "READ_ALL",
#    "creatable": false,
#    "deletable": false,
#    "permissions": {
#     "d": "READ",
#     "x": "READ",
#     "y": "READ",
#     "z": "READ"
#    }
#   },
#   {
#    "orgId": 1,
#    "typeName": "A",
#    "permissionName": "WRITE_ALL",
#    "creatable": true,
#    "deletable": true,
#    "permissions": {
#     "x": "WRITE",
#     "y": "WRITE",
#     "z": "WRITE",
#     "d": "READ"
#    }
#   }
#  ]
# }
# -------------------------------------
#
# STEP 3
#
# Hash= 12436a50a729da87300cfd6b295c04ec3707e1e82a574c5ecba4c17ac16d32b9
# URL: http://localhost:8080/api/assertion/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "A",
#  "assertionName": "someAssertion",
#  "displayName": "",
#  "assertion": {
#   "op": "==",
#   "types": [
#    "Number"
#   ],
#   "args": [
#    {
#     "op": "%",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "d"
#       ]
#      },
#      3
#     ]
#    },
#    0
#   ]
#  }
# }
#
# RESPONSE: {
#  "orgId": 1,
#  "type": "A",
#  "assertionName": "someAssertion",
#  "assertion": {
#   "op": "==",
#   "types": [
#    "Number"
#   ],
#   "args": [
#    {
#     "op": "%",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "d"
#       ]
#      },
#      3
#     ]
#    },
#    0
#   ]
#  }
# }
# -------------------------------------
#
# STEP 4
#
# Hash= d5547fa8edbd5e76c997b9dccf3df21ec2247b1bf66df7d85b23558eb7d9ca6b
# URL: http://localhost:8080/api/type/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "autoId": true,
#  "keys": {
#   "a": {
#    "type": "Number",
#    "order": "1"
#   },
#   "b": {
#    "type": "Number",
#    "order": "2"
#   },
#   "c": {
#    "type": "A",
#    "order": "3"
#   },
#   "d": {
#    "type": "Formula",
#    "order": "4",
#    "returnType": "Number",
#    "expression": {
#     "op": "+",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "c",
#        "d"
#       ]
#      },
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "a"
#       ]
#      }
#     ]
#    }
#   }
#  },
#  "permissions": [],
#  "roles": {
#   "ADMIN": [
#    "WRITE_ALL"
#   ],
#   "USER": [
#    "READ_ALL"
#   ]
#  }
# }
#
# RESPONSE: {
#  "orgId": 1,
#  "typeName": "B",
#  "keys": {
#   "a": {
#    "order": 1,
#    "type": "Number",
#    "default": 0
#   },
#   "b": {
#    "order": 2,
#    "type": "Number",
#    "default": 0
#   },
#   "c": {
#    "order": 3,
#    "type": "A"
#   },
#   "d": {
#    "order": 4,
#    "type": "Formula",
#    "returnType": "Number",
#    "expression": {
#     "op": "+",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "c",
#        "d"
#       ]
#      },
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "a"
#       ]
#      }
#     ]
#    },
#    "symbols": [
#     "a",
#     "c.d"
#    ]
#   }
#  },
#  "permissions": [
#   {
#    "orgId": 1,
#    "typeName": "B",
#    "permissionName": "READ_ALL",
#    "creatable": false,
#    "deletable": false,
#    "permissions": {
#     "a": "READ",
#     "b": "READ",
#     "c": "READ",
#     "d": "READ"
#    }
#   },
#   {
#    "orgId": 1,
#    "typeName": "B",
#    "permissionName": "WRITE_ALL",
#    "creatable": true,
#    "deletable": true,
#    "permissions": {
#     "a": "WRITE",
#     "b": "WRITE",
#     "c": "WRITE",
#     "d": "READ"
#    }
#   }
#  ]
# }
# -------------------------------------
#
# STEP 5
#
# Hash= cfe343bcf81fcf91a2a887dd4d23648112f8ab776a3069987229259c3cb54d5d
# URL: http://localhost:8080/api/assertion/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "assertionName": "someAssertion",
#  "displayName": "",
#  "assertion": {
#   "op": "==",
#   "types": [
#    "Number"
#   ],
#   "args": [
#    {
#     "op": "%",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "d"
#       ]
#      },
#      5
#     ]
#    },
#    0
#   ]
#  }
# }
#
# RESPONSE: {
#  "orgId": 1,
#  "type": "B",
#  "assertionName": "someAssertion",
#  "assertion": {
#   "op": "==",
#   "types": [
#    "Number"
#   ],
#   "args": [
#    {
#     "op": "%",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "d"
#       ]
#      },
#      5
#     ]
#    },
#    0
#   ]
#  }
# }
# -------------------------------------
#
# STEP 6
#
# Hash= 058db7a1313f0ff6425c2bd4f2443fdd28ceaa914f6cb89738c5ef0ffaa6ef8e
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "A",
#  "variableName": "var",
#  "values": {
#   "x": 1,
#   "y": 2,
#   "z": 3
#  }
# }
#
# RESPONSE: {
#  "organization": 1,
#  "typeName": "A",
#  "active": true,
#  "variableName": "1",
#  "values": {
#   "x": 1,
#   "y": 2,
#   "z": 3,
#   "d": 3
#  }
# }
# -------------------------------------
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# config
# run_count 29
# STEP 1
#
# Hash= 0765103a979481c6cea94f4322bd5b69f2365d5f934e69e388dcebdb2b347565
# URL: http://localhost:8080/api/organization/create
#
# REQUEST: {
#  "organization": "pibity",
#  "admin": "admin@xyz.com",
#  "firstName": "Admin",
#  "lastName": "",
#  "password": "1234",
#  "details": {}
# }
#
# RESPONSE: {
#  "id": 1,
#  "name": "pibity"
# }
# -------------------------------------
#
# STEP 2
#
# Hash= ffb586769be7fc3963c3ee203d23ad2e82d8b97bb90605b5bef1c6b310d8747c
# URL: http://localhost:8080/api/type/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "A",
#  "displayName": "A",
#  "autoId": true,
#  "keys": {
#   "x": {
#    "type": "Number",
#    "order": "1"
#   },
#   "y": {
#    "type": "Number",
#    "order": "2"
#   },
#   "z": {
#    "type": "Number",
#    "order": "3"
#   },
#   "d": {
#    "type": "Formula",
#    "order": "4",
#    "returnType": "Number",
#    "expression": {
#     "op": "+",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "x"
#       ]
#      },
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "y"
#       ]
#      }
#     ]
#    }
#   }
#  },
#  "permissions": [],
#  "roles": {
#   "ADMIN": [
#    "WRITE_ALL"
#   ],
#   "USER": [
#    "READ_ALL"
#   ]
#  }
# }
#
# RESPONSE: {
#  "orgId": 1,
#  "typeName": "A",
#  "keys": {
#   "x": {
#    "order": 1,
#    "type": "Number",
#    "default": 0
#   },
#   "y": {
#    "order": 2,
#    "type": "Number",
#    "default": 0
#   },
#   "z": {
#    "order": 3,
#    "type": "Number",
#    "default": 0
#   },
#   "d": {
#    "order": 4,
#    "type": "Formula",
#    "returnType": "Number",
#    "expression": {
#     "op": "+",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "x"
#       ]
#      },
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "y"
#       ]
#      }
#     ]
#    },
#    "symbols": [
#     "x",
#     "y"
#    ]
#   }
#  },
#  "permissions": [
#   {
#    "orgId": 1,
#    "typeName": "A",
#    "permissionName": "READ_ALL",
#    "creatable": false,
#    "deletable": false,
#    "permissions": {
#     "d": "READ",
#     "x": "READ",
#     "y": "READ",
#     "z": "READ"
#    }
#   },
#   {
#    "orgId": 1,
#    "typeName": "A",
#    "permissionName": "WRITE_ALL",
#    "creatable": true,
#    "deletable": true,
#    "permissions": {
#     "x": "WRITE",
#     "y": "WRITE",
#     "z": "WRITE",
#     "d": "READ"
#    }
#   }
#  ]
# }
# -------------------------------------
#
# STEP 3
#
# Hash= 12436a50a729da87300cfd6b295c04ec3707e1e82a574c5ecba4c17ac16d32b9
# URL: http://localhost:8080/api/assertion/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "A",
#  "assertionName": "someAssertion",
#  "displayName": "",
#  "assertion": {
#   "op": "==",
#   "types": [
#    "Number"
#   ],
#   "args": [
#    {
#     "op": "%",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "d"
#       ]
#      },
#      3
#     ]
#    },
#    0
#   ]
#  }
# }
#
# RESPONSE: {
#  "orgId": 1,
#  "type": "A",
#  "assertionName": "someAssertion",
#  "assertion": {
#   "op": "==",
#   "types": [
#    "Number"
#   ],
#   "args": [
#    {
#     "op": "%",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "d"
#       ]
#      },
#      3
#     ]
#    },
#    0
#   ]
#  }
# }
# -------------------------------------
#
# STEP 4
#
# Hash= d5547fa8edbd5e76c997b9dccf3df21ec2247b1bf66df7d85b23558eb7d9ca6b
# URL: http://localhost:8080/api/type/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "autoId": true,
#  "keys": {
#   "a": {
#    "type": "Number",
#    "order": "1"
#   },
#   "b": {
#    "type": "Number",
#    "order": "2"
#   },
#   "c": {
#    "type": "A",
#    "order": "3"
#   },
#   "d": {
#    "type": "Formula",
#    "order": "4",
#    "returnType": "Number",
#    "expression": {
#     "op": "+",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "c",
#        "d"
#       ]
#      },
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "a"
#       ]
#      }
#     ]
#    }
#   }
#  },
#  "permissions": [],
#  "roles": {
#   "ADMIN": [
#    "WRITE_ALL"
#   ],
#   "USER": [
#    "READ_ALL"
#   ]
#  }
# }
#
# RESPONSE: {
#  "orgId": 1,
#  "typeName": "B",
#  "keys": {
#   "a": {
#    "order": 1,
#    "type": "Number",
#    "default": 0
#   },
#   "b": {
#    "order": 2,
#    "type": "Number",
#    "default": 0
#   },
#   "c": {
#    "order": 3,
#    "type": "A"
#   },
#   "d": {
#    "order": 4,
#    "type": "Formula",
#    "returnType": "Number",
#    "expression": {
#     "op": "+",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "c",
#        "d"
#       ]
#      },
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "a"
#       ]
#      }
#     ]
#    },
#    "symbols": [
#     "a",
#     "c.d"
#    ]
#   }
#  },
#  "permissions": [
#   {
#    "orgId": 1,
#    "typeName": "B",
#    "permissionName": "READ_ALL",
#    "creatable": false,
#    "deletable": false,
#    "permissions": {
#     "a": "READ",
#     "b": "READ",
#     "c": "READ",
#     "d": "READ"
#    }
#   },
#   {
#    "orgId": 1,
#    "typeName": "B",
#    "permissionName": "WRITE_ALL",
#    "creatable": true,
#    "deletable": true,
#    "permissions": {
#     "a": "WRITE",
#     "b": "WRITE",
#     "c": "WRITE",
#     "d": "READ"
#    }
#   }
#  ]
# }
# -------------------------------------
#
# STEP 5
#
# Hash= cfe343bcf81fcf91a2a887dd4d23648112f8ab776a3069987229259c3cb54d5d
# URL: http://localhost:8080/api/assertion/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "assertionName": "someAssertion",
#  "displayName": "",
#  "assertion": {
#   "op": "==",
#   "types": [
#    "Number"
#   ],
#   "args": [
#    {
#     "op": "%",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "d"
#       ]
#      },
#      5
#     ]
#    },
#    0
#   ]
#  }
# }
#
# RESPONSE: {
#  "orgId": 1,
#  "type": "B",
#  "assertionName": "someAssertion",
#  "assertion": {
#   "op": "==",
#   "types": [
#    "Number"
#   ],
#   "args": [
#    {
#     "op": "%",
#     "types": [
#      "Number"
#     ],
#     "args": [
#      {
#       "op": ".",
#       "types": [
#        "Number"
#       ],
#       "args": [
#        "d"
#       ]
#      },
#      5
#     ]
#    },
#    0
#   ]
#  }
# }
# -------------------------------------
#
# STEP 6
#
# Hash= 058db7a1313f0ff6425c2bd4f2443fdd28ceaa914f6cb89738c5ef0ffaa6ef8e
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "A",
#  "variableName": "var",
#  "values": {
#   "x": 1,
#   "y": 2,
#   "z": 3
#  }
# }
#
# RESPONSE: {
#  "organization": 1,
#  "typeName": "A",
#  "active": true,
#  "variableName": "1",
#  "values": {
#   "x": 1,
#   "y": 2,
#   "z": 3,
#   "d": 3
#  }
# }
# -------------------------------------
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# ...
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
#
# STEP 7
#
# Hash= b43fa117ab30ce68585122acade94e0163d11f5dbe1a578179534f79651fa318
# URL: http://localhost:8080/api/variable/create
#
# REQUEST: {
#  "orgId": 1,
#  "typeName": "B",
#  "variableName": "var",
#  "values": {
#   "a": 4,
#   "b": 1,
#   "c": 1
#  }
# }
#
# STATUS CODE: 400
# ERROR: {
#  "variableName": "Failed to assert someAssertion"
# }
# STOPPING EXECUTION
# SKIPPING STEP 1
#
# SKIPPING STEP 2
#
# SKIPPING STEP 3
#
# SKIPPING STEP 4
#
# SKIPPING STEP 5
#
# SKIPPING STEP 6
